# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/eng521/Grasp Point Prediction"
# !git config --global user.email "priyagautham28@gmail.com"
# !git config --global user.name "Priyadarshini Rajmohan"
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/eng521/Grasp Point Prediction

# %%
# !git remote add origin https://token@github.com/priyagautham28/grasp-point-prediction.git
# !git branch -M main

# %%
import nbformat

path = '/content/drive/MyDrive/eng521/Grasp Point Prediction/notebooks/Clip_v2.ipynb'
nb = nbformat.read(path, as_version=4)

# Remove the problematic widget metadata
if 'widgets' in nb.metadata:
    del nb.metadata['widgets']

nbformat.write(nb, path)
print('Fixed')
# Out:
# Fixed

# %%
# !git pull origin main
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 1.04 KiB | 1024 bytes/s, done.
# From https://github.com/priyagautham28/grasp-point-prediction
#  * branch            main       -> FETCH_HEAD
#    455d89d..6c625ea  main       -> origin/main
# Updating 455d89d..6c625ea
# ^C

# %%
# 1. Check what changed
# !git status

# 2. Add the changed files
# !git add notebooks/Clip_model_v3.ipynb          # or specific file: !git add notebooks/Clip_model_v3.ipynb

# 3. Commit with a message
# !git commit -m "fix: remove widget metadata for GitHub rendering"

# 4. Push to GitHub
# !git push origin main
# Out:
# [main a62ee67] fix: remove widget metadata for GitHub rendering
#  6 files changed, 7935 insertions(+), 5 deletions(-)
#  rewrite notebooks/Clip_model_baseline_v1.ipynb (87%)
#  rewrite notebooks/Clip_model_v3.ipynb (97%)
#  rewrite notebooks/Clip_model_v3_patch16.ipynb (98%)
#  rewrite notebooks/Clip_v2.ipynb (83%)
#  create mode 100644 notebooks/GroundingDINO_Prelimnary_Results.ipynb
# Enumerating objects: 16, done.
# Counting objects: 100% (16/16), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (9/9), 1001.66 KiB | 4.04 MiB/s, done.
# Total 9 (delta 7), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (7/7), completed with 6 local objects.
# To https://github.com/priyagautham28/grasp-point-prediction.git
#    3f25f42..a62ee67  main -> main

# %%
# !git add outputs/evaluation/fig_combined_4panel.png
# !git add outputs/evaluation/fig_combined_4panel.pdf

# !git commit -m "Added evaluation files"
# !git push origin main
# Out:
# [main 5290bfc] Added evaluation files
#  2 files changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 outputs/evaluation/fig_combined_4panel.pdf
#  create mode 100644 outputs/evaluation/fig_combined_4panel.png
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 454.16 KiB | 7.83 MiB/s, done.
# Total 6 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/priyagautham28/grasp-point-prediction.git
#    70cc19c..5290bfc  main -> main

# %%
# !git rm -r --cached git/
# !git commit -m "removed folder"
# !git push
# Out:
# rm 'git/git_commit.ipynb'
# rm 'git/git_commit_florence2.ipynb'
# [main 1dd5a3f] removed folder
#  2 files changed, 2 deletions(-)
#  delete mode 100644 git/git_commit.ipynb
#  delete mode 100644 git/git_commit_florence2.ipynb
# To https://github.com/priyagautham28/grasp-point-prediction.git
#  ! [rejected]        main -> main (non-fast-forward)
# error: failed to push some refs to 'https://github.com/priyagautham28/grasp-point-prediction.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. Integrate the remote changes (e.g.
# hint: 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.
